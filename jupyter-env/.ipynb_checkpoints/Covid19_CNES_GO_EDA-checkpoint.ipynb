# %% [markdown]
# ![image.png](attachment:image.png)
#
# ---
# **Sugestões de Análise:**
# * **Comparar a distribuição geográfica dos leitos por município antes e depois da pandemia**
# * **Analisar a evolução do número de leitos no tempo**
# * **Verificar se em algum momento pôde ser observado um declínio na capacidade hospitalar instalada**
# * **Comparar a quantidade de leitos SUS e leitos não SUS no tempo e no espaço**

# %% [markdown]
# ---

# %% [markdown]
# # 1. Carregando as dependências do projeto

# %%
# sistema
from os import system

# manipulação e tratamento de dados tabulares
import pandas as pd
import pysus.online_data.CNES as CNES
import pandasql as ps

# bibliotecas numéricas
import numpy as np

# bibliotecas de visualização e estatítica
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ---

# %% [markdown]
# # 2. Carregando a base de dados
#
# **Tendo o objetivo de realizar uma análise exploratória para descrever a evolução da capacidade hospitalar (número de leitos) durante a pandemia de Covid-19 em Goiás, podemos considerar como período ```dez/2019``` (que foi tido como o primeiro mês do início da pandemia) até ```nov/2022``` (que é o último mês registrado na base de dados original antes da elaboração do presente relatório).**
#
# **Além disso, iremos criar variáveis para representar uma estrutura tabular de dados ("dataframe") seguindo o padrão ```df_mes_ano```, em que:**
# * **mes: 2 dígitos numéricos (01-12), representando o mês a ser utilizado para consulta**
# * **ano: 2 dígitos numéricos, representando os dois últimos digitos do ano a ser utilizado para consulta**

# %%
# Verificando a data atual
system('date')
# Out:
# Thu Dec 29 11:35:52 AM -03 2022
# 0

# %% [markdown]
# **Desta forma, iremos manter o período descrito anteriormente como sendo a filtragem para gerar nossa base de dados. Além disso, vamos criar uma função para facilitar a leitura desses dados.**

# %%
def loadDataSUS(year,month,params={
    'group':'LT',
    'state':'GO'
}):
    df = CNES.download(params['group'],params['state'],year,month)
    df = pd.DataFrame(df) # convertendo em objeto Pandas
    if params['group'] == 'LT':
        # criando novos campos
        df['ano'] = [val.strip()[0:4] for val in df['COMPETEN']]
        df['mes'] = [val.strip()[4:] for val in df['COMPETEN']]
    return df

# %% [markdown]
# ## (i) 2019

# %%
df_12_19 = loadDataSUS(2019,12)
df_12_19
# Out:
# 2022-12-30 15:15:48.782 | DEBUG    | pysus.online_data.CNES:download:64 - Stablishing connection with ftp.datasus.gov.br.
# 220 Microsoft FTP Service
# 2022-12-30 15:15:48.810 | DEBUG    | pysus.online_data.CNES:download:69 - Changing FTP work dir to: dissemin/publicos/CNES/200508_/Dados/LT/
# 2022-12-30 15:15:49.147 | DEBUG    | pysus.online_data.CNES:_fetch_file:99 - LTGO1912.dbc removed.
# 2022-12-30 15:15:49.425 | INFO     | pysus.online_data.CNES:download:83 - Data stored as parquet at /home/noetic-sierra/pysus/CNES_LTGO1912_.parquet
#          CNES CODUFMUN REGSAUDE MICR_REG DISTRSAN DISTRADM TPGESTAO PF_PJ  \
# 0     9331603   520010                                            M     3
# 1     2335506   520013       15                                   M     3
# 2     2335506   520013       15                                   M     3
# 3     2335506   520013       15                                   M     3
# 4     2335506   520013       15                                   M     3
# ...       ...      ...      ...      ...      ...      ...      ...   ...
# 2805  2383691   522205      001                                   M     3
# 2806  2383691   522205      001                                   M     3
# 2807  2439883   522220       02                                   M     3
# 2808  2439883   522220       02                                   M     3
# 2809  2439883   522220       02                                   M     3
#
#             CPF_CNPJ NIV_DEP  ... TP_LEITO CODLEITO QT_EXIST QT_CONTR QT_SUS  \
# 0     00000000000000       3  ...        2       33        9        0      9
# 1     00269860000125       1  ...        2       41        2        0      2
# 2     00269860000125       1  ...        1       03        2        0      1
# 3     00269860000125       1  ...        4       10        1        0      1
# 4     00269860000125       1  ...        6       34        4        0      3
# ...              ...     ...  ...      ...      ...      ...      ...    ...
# 2805  00000000000000       3  ...        4       43        1        0      1
# 2806  00000000000000       3  ...        5       45        3        0      3
# 2807  00000000000000       3  ...        5       45        4        0      4
# 2808  00000000000000       3  ...        2       33        7        0      7
# 2809  00000000000000       3  ...        4       43        2        0      2
#
#      QT_NSUS COMPETEN NAT_JUR   ano mes
# 0          0   201912    1244  2019  12
# 1          0   201912    2062  2019  12
# 2          1   201912    2062  2019  12
# 3          0   201912    2062  2019  12
# 4          1   201912    2062  2019  12
# ...      ...      ...     ...   ...  ..
# 2805       0   201912    1244  2019  12
# 2806       0   201912    1244  2019  12
# 2807       0   201912    1244  2019  12
# 2808       0   201912    1244  2019  12
# 2809       0   201912    1244  2019  12
#
# [2810 rows x 30 columns]

# %% [markdown]
# ## (ii) 2020

# %%
df_01_20 = loadDataSUS(2020,1)
df_02_20 = loadDataSUS(2020,2)
df_03_20 = loadDataSUS(2020,3)
df_04_20 = loadDataSUS(2020,4)
df_05_20 = loadDataSUS(2020,5)
df_06_20 = loadDataSUS(2020,6)
df_07_20 = loadDataSUS(2020,7)
df_08_20 = loadDataSUS(2020,8)
df_09_20 = loadDataSUS(2020,9)
df_10_20 = loadDataSUS(2020,10)
df_11_20 = loadDataSUS(2020,11)
df_12_20 = loadDataSUS(2020,12)
# Out:
# 2022-12-30 15:15:57.904 | DEBUG    | pysus.online_data.CNES:download:64 - Stablishing connection with ftp.datasus.gov.br.
# 220 Microsoft FTP Service
# 2022-12-30 15:15:57.934 | DEBUG    | pysus.online_data.CNES:download:69 - Changing FTP work dir to: dissemin/publicos/CNES/200508_/Dados/LT/
# 2022-12-30 15:15:58.245 | DEBUG    | pysus.online_data.CNES:_fetch_file:99 - LTGO2001.dbc removed.
# 2022-12-30 15:15:58.258 | INFO     | pysus.online_data.CNES:download:83 - Data stored as parquet at /home/noetic-sierra/pysus/CNES_LTGO2001_.parquet
# 2022-12-30 15:15:58.441 | DEBUG    | pysus.online_data.CNES:download:64 - Stablishing connection with ftp.datasus.gov.br.
# 220 Microsoft FTP Service
# 2022-12-30 15:15:58.474 | DEBUG    | pysus.online_data.CNES:download:69 - Changing FTP work dir to: dissemin/publicos/CNES/200508_/Dados/LT/
# 2022-12-30 15:15:58.808 | DEBUG    | pysus.online_data.CNES:_fetch_file:99 - LTGO2002.dbc removed.
# 2022-12-30 15:15:58.828 | INFO     | pysus.online_data.CNES:download:83 - Data stored as parquet at /home/noetic-sierra/pysus/CNES_LTGO2002_.parquet
# 2022-12-30 15:15:58.958 | DEBUG    | pysus.online_data.CNES:download:64 - Stablishing connection with ftp.datasus.gov.br.
# 220 Microsoft FTP Service
# 2022-12-30 15:15:58.987 | DEBUG    | pysus.online_data.CNES:download:69 - Changing FTP work dir to: dissemin/publicos/CNES/200508_/Dados/LT/
# 2022-12-30 15:15:59.303 | DEBUG    | pysus.online_data.CNES:_fetch_file:99 - LTGO2003.dbc removed.
# 2022-12-30 15:15:59.316 | INFO     | pysus.online_data.CNES:download:83 - Data stored as parquet at /home/noetic-sierra/pysus/CNES_LTGO2003_.parquet
# 2022-12-30 15:15:59.469 | DEBUG    | pysus.online_data.CNES:download:64 - Stablishing connection with ftp.datasus.gov.br.
# 220 Microsoft FTP Service
# 2022-12-30 15:15:59.503 | DEBUG    | pysus.online_data.CNES:download:69 - Changing FTP work dir to: dissemin/publicos/CNES/200508_/Dados/LT/
# 2022-12-30 15:15:59.820 | DEBUG    | pysus.online_data.CNES:_fetch_file:99 - LTGO2004.dbc removed.
# 2022-12-30 15:15:59.831 | INFO     | pysus.online_data.CNES:download:83 - Data stored as parquet at /home/noetic-sierra/pysus/CNES_LTGO2004_.parquet
# 2022-12-30 15:16:00.051 | DEBUG    | pysus.online_data.CNES:download:64 - Stablishing connection with ftp.datasus.gov.br.
# 220 Microsoft FTP Service
# 2022-12-30 15:16:00.079 | DEBUG    | pysus.online_data.CNES:download:69 - Changing FTP work dir to: dissemin/publicos/CNES/200508_/Dados/LT/
# 2022-12-30 15:16:00.412 | DEBUG    | pysus.online_data.CNES:_fetch_file:99 - LTGO2005.dbc removed.
# 2022-12-30 15:16:00.423 | INFO     | pysus.online_data.CNES:download:83 - Data stored as parquet at /home/noetic-sierra/pysus/CNES_LTGO2005_.parquet
# 2022-12-30 15:16:00.551 | DEBUG    | pysus.online_data.CNES:download:64 - Stablishing connection with ftp.datasus.gov.br.
# 220 Microsoft FTP Service
# 2022-12-30 15:16:00.581 | DEBUG    | pysus.online_data.CNES:download:69 - Changing FTP work dir to: dissemin/publicos/CNES/200508_/Dados/LT/
# 2022-12-30 15:16:00.931 | DEBUG    | pysus.online_data.CNES:_fetch_file:99 - LTGO2006.dbc removed.
# 2022-12-30 15:16:00.949 | INFO     | pysus.online_data.CNES:download:83 - Data stored as parquet at /home/noetic-sierra/pysus/CNES_LTGO2006_.parquet
# 2022-12-30 15:16:01.090 | DEBUG    | pysus.online_data.CNES:download:64 - Stablishing connection with ftp.datasus.gov.br.
# 220 Microsoft FTP Service
# 2022-12-30 15:16:01.119 | DEBUG    | pysus.online_data.CNES:download:69 - Changing FTP work dir to: dissemin/publicos/CNES/200508_/Dados/LT/
# 2022-12-30 15:16:01.420 | DEBUG    | pysus.online_data.CNES:_fetch_file:99 - LTGO2007.dbc removed.
# 2022-12-30 15:16:01.432 | INFO     | pysus.online_data.CNES:download:83 - Data stored as parquet at /home/noetic-sierra/pysus/CNES_LTGO2007_.parquet
# 2022-12-30 15:16:01.572 | DEBUG    | pysus.online_data.CNES:download:64 - Stablishing connection with ftp.datasus.gov.br.
# 220 Microsoft FTP Service
# 2022-12-30 15:16:01.601 | DEBUG    | pysus.online_data.CNES:download:69 - Changing FTP work dir to: dissemin/publicos/CNES/200508_/Dados/LT/
# 2022-12-30 15:16:01.950 | DEBUG    | pysus.online_data.CNES:_fetch_file:99 - LTGO2008.dbc removed.
# 2022-12-30 15:16:01.961 | INFO     | pysus.online_data.CNES:download:83 - Data stored as parquet at /home/noetic-sierra/pysus/CNES_LTGO2008_.parquet
# 2022-12-30 15:16:02.179 | DEBUG    | pysus.online_data.CNES:download:64 - Stablishing connection with ftp.datasus.gov.br.
# 220 Microsoft FTP Service
# 2022-12-30 15:16:02.207 | DEBUG    | pysus.online_data.CNES:download:69 - Changing FTP work dir to: dissemin/publicos/CNES/200508_/Dados/LT/
# 2022-12-30 15:16:02.541 | DEBUG    | pysus.online_data.CNES:_fetch_file:99 - LTGO2009.dbc removed.
# 2022-12-30 15:16:02.555 | INFO     | pysus.online_data.CNES:download:83 - Data stored as parquet at /home/noetic-sierra/pysus/CNES_LTGO2009_.parquet
# 2022-12-30 15:16:02.702 | DEBUG    | pysus.online_data.CNES:download:64 - Stablishing connection with ftp.datasus.gov.br.
# 220 Microsoft FTP Service
# 2022-12-30 15:16:02.731 | DEBUG    | pysus.online_data.CNES:download:69 - Changing FTP work dir to: dissemin/publicos/CNES/200508_/Dados/LT/
# 2022-12-30 15:16:03.069 | DEBUG    | pysus.online_data.CNES:_fetch_file:99 - LTGO2010.dbc removed.
# 2022-12-30 15:16:03.082 | INFO     | pysus.online_data.CNES:download:83 - Data stored as parquet at /home/noetic-sierra/pysus/CNES_LTGO2010_.parquet
# 2022-12-30 15:16:03.216 | DEBUG    | pysus.online_data.CNES:download:64 - Stablishing connection with ftp.datasus.gov.br.
# 220 Microsoft FTP Service
# 2022-12-30 15:16:03.252 | DEBUG    | pysus.online_data.CNES:download:69 - Changing FTP work dir to: dissemin/publicos/CNES/200508_/Dados/LT/
# 2022-12-30 15:16:03.645 | DEBUG    | pysus.online_data.CNES:_fetch_file:99 - LTGO2011.dbc removed.
# 2022-12-30 15:16:03.664 | INFO     | pysus.online_data.CNES:download:83 - Data stored as parquet at /home/noetic-sierra/pysus/CNES_LTGO2011_.parquet
# 2022-12-30 15:16:03.785 | DEBUG    | pysus.online_data.CNES:download:64 - Stablishing connection with ftp.datasus.gov.br.
# 220 Microsoft FTP Service
# 2022-12-30 15:16:03.815 | DEBUG    | pysus.online_data.CNES:download:69 - Changing FTP work dir to: dissemin/publicos/CNES/200508_/Dados/LT/
# 2022-12-30 15:16:04.183 | DEBUG    | pysus.online_data.CNES:_fetch_file:99 - LTGO2012.dbc removed.
# 2022-12-30 15:16:04.201 | INFO     | pysus.online_data.CNES:download:83 - Data stored as parquet at /home/noetic-sierra/pysus/CNES_LTGO2012_.parquet

# %% [markdown]
# ## (iii) 2021

# %%
df_01_21 = loadDataSUS(2021,1)
df_02_21 = loadDataSUS(2021,2)
df_03_21 = loadDataSUS(2021,3)
df_04_21 = loadDataSUS(2021,4)
df_05_21 = loadDataSUS(2021,5)
df_06_21 = loadDataSUS(2021,6)
df_07_21 = loadDataSUS(2021,7)
df_08_21 = loadDataSUS(2021,8)
df_09_21 = loadDataSUS(2021,9)
df_10_21 = loadDataSUS(2021,10)
df_11_21 = loadDataSUS(2021,11)
df_12_21 = loadDataSUS(2021,12)
# Out:
# 2022-12-30 15:16:04.326 | DEBUG    | pysus.online_data.CNES:download:64 - Stablishing connection with ftp.datasus.gov.br.
# 220 Microsoft FTP Service
# 2022-12-30 15:16:04.355 | DEBUG    | pysus.online_data.CNES:download:69 - Changing FTP work dir to: dissemin/publicos/CNES/200508_/Dados/LT/
# 2022-12-30 15:16:04.674 | DEBUG    | pysus.online_data.CNES:_fetch_file:99 - LTGO2101.dbc removed.
# 2022-12-30 15:16:04.692 | INFO     | pysus.online_data.CNES:download:83 - Data stored as parquet at /home/noetic-sierra/pysus/CNES_LTGO2101_.parquet
# 2022-12-30 15:16:04.809 | DEBUG    | pysus.online_data.CNES:download:64 - Stablishing connection with ftp.datasus.gov.br.
# 220 Microsoft FTP Service
# 2022-12-30 15:16:04.841 | DEBUG    | pysus.online_data.CNES:download:69 - Changing FTP work dir to: dissemin/publicos/CNES/200508_/Dados/LT/
# 2022-12-30 15:16:05.158 | DEBUG    | pysus.online_data.CNES:_fetch_file:99 - LTGO2102.dbc removed.
# 2022-12-30 15:16:05.174 | INFO     | pysus.online_data.CNES:download:83 - Data stored as parquet at /home/noetic-sierra/pysus/CNES_LTGO2102_.parquet
# 2022-12-30 15:16:05.300 | DEBUG    | pysus.online_data.CNES:download:64 - Stablishing connection with ftp.datasus.gov.br.
# 220 Microsoft FTP Service
# 2022-12-30 15:16:05.330 | DEBUG    | pysus.online_data.CNES:download:69 - Changing FTP work dir to: dissemin/publicos/CNES/200508_/Dados/LT/
# 2022-12-30 15:16:05.665 | DEBUG    | pysus.online_data.CNES:_fetch_file:99 - LTGO2103.dbc removed.
# 2022-12-30 15:16:05.682 | INFO     | pysus.online_data.CNES:download:83 - Data stored as parquet at /home/noetic-sierra/pysus/CNES_LTGO2103_.parquet
# 2022-12-30 15:16:05.802 | DEBUG    | pysus.online_data.CNES:download:64 - Stablishing connection with ftp.datasus.gov.br.
# 220 Microsoft FTP Service
# 2022-12-30 15:16:05.832 | DEBUG    | pysus.online_data.CNES:download:69 - Changing FTP work dir to: dissemin/publicos/CNES/200508_/Dados/LT/
# 2022-12-30 15:16:06.180 | DEBUG    | pysus.online_data.CNES:_fetch_file:99 - LTGO2104.dbc removed.
# 2022-12-30 15:16:06.196 | INFO     | pysus.online_data.CNES:download:83 - Data stored as parquet at /home/noetic-sierra/pysus/CNES_LTGO2104_.parquet
# 2022-12-30 15:16:06.321 | DEBUG    | pysus.online_data.CNES:download:64 - Stablishing connection with ftp.datasus.gov.br.
# 220 Microsoft FTP Service
# 2022-12-30 15:16:06.348 | DEBUG    | pysus.online_data.CNES:download:69 - Changing FTP work dir to: dissemin/publicos/CNES/200508_/Dados/LT/
# 2022-12-30 15:16:06.658 | DEBUG    | pysus.online_data.CNES:_fetch_file:99 - LTGO2105.dbc removed.
# 2022-12-30 15:16:06.670 | INFO     | pysus.online_data.CNES:download:83 - Data stored as parquet at /home/noetic-sierra/pysus/CNES_LTGO2105_.parquet
# 2022-12-30 15:16:06.799 | DEBUG    | pysus.online_data.CNES:download:64 - Stablishing connection with ftp.datasus.gov.br.
# 220 Microsoft FTP Service
# 2022-12-30 15:16:06.826 | DEBUG    | pysus.online_data.CNES:download:69 - Changing FTP work dir to: dissemin/publicos/CNES/200508_/Dados/LT/
# 2022-12-30 15:16:07.169 | DEBUG    | pysus.online_data.CNES:_fetch_file:99 - LTGO2106.dbc removed.
# 2022-12-30 15:16:07.187 | INFO     | pysus.online_data.CNES:download:83 - Data stored as parquet at /home/noetic-sierra/pysus/CNES_LTGO2106_.parquet
# 2022-12-30 15:16:07.302 | DEBUG    | pysus.online_data.CNES:download:64 - Stablishing connection with ftp.datasus.gov.br.
# 220 Microsoft FTP Service
# 2022-12-30 15:16:07.331 | DEBUG    | pysus.online_data.CNES:download:69 - Changing FTP work dir to: dissemin/publicos/CNES/200508_/Dados/LT/
# 2022-12-30 15:16:07.649 | DEBUG    | pysus.online_data.CNES:_fetch_file:99 - LTGO2107.dbc removed.
# 2022-12-30 15:16:07.667 | INFO     | pysus.online_data.CNES:download:83 - Data stored as parquet at /home/noetic-sierra/pysus/CNES_LTGO2107_.parquet
# 2022-12-30 15:16:07.786 | DEBUG    | pysus.online_data.CNES:download:64 - Stablishing connection with ftp.datasus.gov.br.
# 220 Microsoft FTP Service
# 2022-12-30 15:16:07.815 | DEBUG    | pysus.online_data.CNES:download:69 - Changing FTP work dir to: dissemin/publicos/CNES/200508_/Dados/LT/
# 2022-12-30 15:16:08.142 | DEBUG    | pysus.online_data.CNES:_fetch_file:99 - LTGO2108.dbc removed.
# 2022-12-30 15:16:08.154 | INFO     | pysus.online_data.CNES:download:83 - Data stored as parquet at /home/noetic-sierra/pysus/CNES_LTGO2108_.parquet
# 2022-12-30 15:16:08.271 | DEBUG    | pysus.online_data.CNES:download:64 - Stablishing connection with ftp.datasus.gov.br.
# 220 Microsoft FTP Service
# 2022-12-30 15:16:08.300 | DEBUG    | pysus.online_data.CNES:download:69 - Changing FTP work dir to: dissemin/publicos/CNES/200508_/Dados/LT/
# 2022-12-30 15:16:08.624 | DEBUG    | pysus.online_data.CNES:_fetch_file:99 - LTGO2109.dbc removed.
# 2022-12-30 15:16:08.640 | INFO     | pysus.online_data.CNES:download:83 - Data stored as parquet at /home/noetic-sierra/pysus/CNES_LTGO2109_.parquet
# 2022-12-30 15:16:08.767 | DEBUG    | pysus.online_data.CNES:download:64 - Stablishing connection with ftp.datasus.gov.br.
# 220 Microsoft FTP Service
# 2022-12-30 15:16:08.796 | DEBUG    | pysus.online_data.CNES:download:69 - Changing FTP work dir to: dissemin/publicos/CNES/200508_/Dados/LT/
# 2022-12-30 15:16:09.133 | DEBUG    | pysus.online_data.CNES:_fetch_file:99 - LTGO2110.dbc removed.
# 2022-12-30 15:16:09.144 | INFO     | pysus.online_data.CNES:download:83 - Data stored as parquet at /home/noetic-sierra/pysus/CNES_LTGO2110_.parquet
# 2022-12-30 15:16:09.263 | DEBUG    | pysus.online_data.CNES:download:64 - Stablishing connection with ftp.datasus.gov.br.
# 220 Microsoft FTP Service
# 2022-12-30 15:16:09.292 | DEBUG    | pysus.online_data.CNES:download:69 - Changing FTP work dir to: dissemin/publicos/CNES/200508_/Dados/LT/
# 2022-12-30 15:16:09.628 | DEBUG    | pysus.online_data.CNES:_fetch_file:99 - LTGO2111.dbc removed.
# 2022-12-30 15:16:09.643 | INFO     | pysus.online_data.CNES:download:83 - Data stored as parquet at /home/noetic-sierra/pysus/CNES_LTGO2111_.parquet
# 2022-12-30 15:16:09.765 | DEBUG    | pysus.online_data.CNES:download:64 - Stablishing connection with ftp.datasus.gov.br.
# 220 Microsoft FTP Service
# 2022-12-30 15:16:09.795 | DEBUG    | pysus.online_data.CNES:download:69 - Changing FTP work dir to: dissemin/publicos/CNES/200508_/Dados/LT/
# 2022-12-30 15:16:10.123 | DEBUG    | pysus.online_data.CNES:_fetch_file:99 - LTGO2112.dbc removed.
# 2022-12-30 15:16:10.142 | INFO     | pysus.online_data.CNES:download:83 - Data stored as parquet at /home/noetic-sierra/pysus/CNES_LTGO2112_.parquet

# %% [markdown]
# ## (iv) 2022

# %%
df_01_22 = loadDataSUS(2022,1)
df_02_22 = loadDataSUS(2022,2)
df_03_22 = loadDataSUS(2022,3)
df_04_22 = loadDataSUS(2022,4)
df_05_22 = loadDataSUS(2022,5)
df_06_22 = loadDataSUS(2022,6)
df_07_22 = loadDataSUS(2022,7)
df_08_22 = loadDataSUS(2022,8)
df_09_22 = loadDataSUS(2022,9)
df_10_22 = loadDataSUS(2022,10)
df_11_22 = loadDataSUS(2022,11)
# Out:
# 2022-12-30 15:16:10.293 | DEBUG    | pysus.online_data.CNES:download:64 - Stablishing connection with ftp.datasus.gov.br.
# 220 Microsoft FTP Service
# 2022-12-30 15:16:10.322 | DEBUG    | pysus.online_data.CNES:download:69 - Changing FTP work dir to: dissemin/publicos/CNES/200508_/Dados/LT/
# 2022-12-30 15:16:10.636 | DEBUG    | pysus.online_data.CNES:_fetch_file:99 - LTGO2201.dbc removed.
# 2022-12-30 15:16:10.648 | INFO     | pysus.online_data.CNES:download:83 - Data stored as parquet at /home/noetic-sierra/pysus/CNES_LTGO2201_.parquet
# 2022-12-30 15:16:10.793 | DEBUG    | pysus.online_data.CNES:download:64 - Stablishing connection with ftp.datasus.gov.br.
# 220 Microsoft FTP Service
# 2022-12-30 15:16:10.823 | DEBUG    | pysus.online_data.CNES:download:69 - Changing FTP work dir to: dissemin/publicos/CNES/200508_/Dados/LT/
# 2022-12-30 15:16:11.143 | DEBUG    | pysus.online_data.CNES:_fetch_file:99 - LTGO2202.dbc removed.
# 2022-12-30 15:16:11.158 | INFO     | pysus.online_data.CNES:download:83 - Data stored as parquet at /home/noetic-sierra/pysus/CNES_LTGO2202_.parquet
# 2022-12-30 15:16:11.309 | DEBUG    | pysus.online_data.CNES:download:64 - Stablishing connection with ftp.datasus.gov.br.
# 220 Microsoft FTP Service
# 2022-12-30 15:16:11.337 | DEBUG    | pysus.online_data.CNES:download:69 - Changing FTP work dir to: dissemin/publicos/CNES/200508_/Dados/LT/
# 2022-12-30 15:16:11.714 | DEBUG    | pysus.online_data.CNES:_fetch_file:99 - LTGO2203.dbc removed.
# 2022-12-30 15:16:11.734 | INFO     | pysus.online_data.CNES:download:83 - Data stored as parquet at /home/noetic-sierra/pysus/CNES_LTGO2203_.parquet
# 2022-12-30 15:16:11.876 | DEBUG    | pysus.online_data.CNES:download:64 - Stablishing connection with ftp.datasus.gov.br.
# 220 Microsoft FTP Service
# 2022-12-30 15:16:11.903 | DEBUG    | pysus.online_data.CNES:download:69 - Changing FTP work dir to: dissemin/publicos/CNES/200508_/Dados/LT/
# 2022-12-30 15:16:12.229 | DEBUG    | pysus.online_data.CNES:_fetch_file:99 - LTGO2204.dbc removed.
# 2022-12-30 15:16:12.241 | INFO     | pysus.online_data.CNES:download:83 - Data stored as parquet at /home/noetic-sierra/pysus/CNES_LTGO2204_.parquet
# 2022-12-30 15:16:12.359 | DEBUG    | pysus.online_data.CNES:download:64 - Stablishing connection with ftp.datasus.gov.br.
# 220 Microsoft FTP Service
# 2022-12-30 15:16:12.389 | DEBUG    | pysus.online_data.CNES:download:69 - Changing FTP work dir to: dissemin/publicos/CNES/200508_/Dados/LT/
# 2022-12-30 15:16:12.703 | DEBUG    | pysus.online_data.CNES:_fetch_file:99 - LTGO2205.dbc removed.
# 2022-12-30 15:16:12.716 | INFO     | pysus.online_data.CNES:download:83 - Data stored as parquet at /home/noetic-sierra/pysus/CNES_LTGO2205_.parquet
# 2022-12-30 15:16:12.849 | DEBUG    | pysus.online_data.CNES:download:64 - Stablishing connection with ftp.datasus.gov.br.
# 220 Microsoft FTP Service
# 2022-12-30 15:16:12.880 | DEBUG    | pysus.online_data.CNES:download:69 - Changing FTP work dir to: dissemin/publicos/CNES/200508_/Dados/LT/
# 2022-12-30 15:16:13.188 | DEBUG    | pysus.online_data.CNES:_fetch_file:99 - LTGO2206.dbc removed.
# 2022-12-30 15:16:13.201 | INFO     | pysus.online_data.CNES:download:83 - Data stored as parquet at /home/noetic-sierra/pysus/CNES_LTGO2206_.parquet
# 2022-12-30 15:16:13.343 | DEBUG    | pysus.online_data.CNES:download:64 - Stablishing connection with ftp.datasus.gov.br.
# 220 Microsoft FTP Service
# 2022-12-30 15:16:13.372 | DEBUG    | pysus.online_data.CNES:download:69 - Changing FTP work dir to: dissemin/publicos/CNES/200508_/Dados/LT/
# 2022-12-30 15:16:13.683 | DEBUG    | pysus.online_data.CNES:_fetch_file:99 - LTGO2207.dbc removed.
# 2022-12-30 15:16:13.697 | INFO     | pysus.online_data.CNES:download:83 - Data stored as parquet at /home/noetic-sierra/pysus/CNES_LTGO2207_.parquet
# 2022-12-30 15:16:13.811 | DEBUG    | pysus.online_data.CNES:download:64 - Stablishing connection with ftp.datasus.gov.br.
# 220 Microsoft FTP Service
# 2022-12-30 15:16:13.839 | DEBUG    | pysus.online_data.CNES:download:69 - Changing FTP work dir to: dissemin/publicos/CNES/200508_/Dados/LT/
# 2022-12-30 15:16:14.139 | DEBUG    | pysus.online_data.CNES:_fetch_file:99 - LTGO2208.dbc removed.
# 2022-12-30 15:16:14.150 | INFO     | pysus.online_data.CNES:download:83 - Data stored as parquet at /home/noetic-sierra/pysus/CNES_LTGO2208_.parquet
# 2022-12-30 15:16:14.285 | DEBUG    | pysus.online_data.CNES:download:64 - Stablishing connection with ftp.datasus.gov.br.
# 220 Microsoft FTP Service
# 2022-12-30 15:16:14.314 | DEBUG    | pysus.online_data.CNES:download:69 - Changing FTP work dir to: dissemin/publicos/CNES/200508_/Dados/LT/
# 2022-12-30 15:16:14.609 | DEBUG    | pysus.online_data.CNES:_fetch_file:99 - LTGO2209.dbc removed.
# 2022-12-30 15:16:14.620 | INFO     | pysus.online_data.CNES:download:83 - Data stored as parquet at /home/noetic-sierra/pysus/CNES_LTGO2209_.parquet
# 2022-12-30 15:16:14.736 | DEBUG    | pysus.online_data.CNES:download:64 - Stablishing connection with ftp.datasus.gov.br.
# 220 Microsoft FTP Service
# 2022-12-30 15:16:14.764 | DEBUG    | pysus.online_data.CNES:download:69 - Changing FTP work dir to: dissemin/publicos/CNES/200508_/Dados/LT/
# 2022-12-30 15:16:15.093 | DEBUG    | pysus.online_data.CNES:_fetch_file:99 - LTGO2210.dbc removed.
# 2022-12-30 15:16:15.110 | INFO     | pysus.online_data.CNES:download:83 - Data stored as parquet at /home/noetic-sierra/pysus/CNES_LTGO2210_.parquet
# 2022-12-30 15:16:15.225 | DEBUG    | pysus.online_data.CNES:download:64 - Stablishing connection with ftp.datasus.gov.br.
# 220 Microsoft FTP Service
# 2022-12-30 15:16:15.252 | DEBUG    | pysus.online_data.CNES:download:69 - Changing FTP work dir to: dissemin/publicos/CNES/200508_/Dados/LT/
# 2022-12-30 15:16:15.572 | DEBUG    | pysus.online_data.CNES:_fetch_file:99 - LTGO2211.dbc removed.
# 2022-12-30 15:16:15.591 | INFO     | pysus.online_data.CNES:download:83 - Data stored as parquet at /home/noetic-sierra/pysus/CNES_LTGO2211_.parquet

# %% [markdown]
# ## (v) Geral: todos os anos

# %%
# Gerando o df principal a partir da concatenação dos anteriores
df_main = pd.concat([
    df_12_19, #2019
    df_01_20,df_02_20,df_03_20,df_04_20,df_05_20,df_06_20,df_07_20,df_08_20,df_09_20,df_10_20,df_11_20,df_12_20, #2020
    df_01_21,df_02_21,df_03_21,df_04_21,df_05_21,df_06_21,df_07_21,df_08_21,df_09_21,df_10_21,df_11_21,df_12_21, #2021
    df_01_22,df_02_22,df_03_22,df_04_22,df_05_22,df_06_20,df_07_22,df_08_22,df_09_22,df_10_22,df_11_22 #2022
])

df_main = df_main[['CODUFMUN','MICR_REG','DISTRADM','TPGESTAO',
                   'PF_PJ','NIV_DEP','ATIVIDAD','CLIENTEL','TP_UNID',
                   'TP_LEITO','QT_EXIST','QT_CONTR','QT_SUS','ano','mes']]

df_main['index'] = [x for x in range(len(df_main))] # criação de um ID para facilitar posteriormente a remoção de linhas duplicadas
df_main
# Out:
#      CODUFMUN MICR_REG DISTRADM TPGESTAO PF_PJ NIV_DEP ATIVIDAD CLIENTEL  \
# 0      520010                          M     3       3       04       03
# 1      520013                          M     3       1       04       03
# 2      520013                          M     3       1       04       03
# 3      520013                          M     3       1       04       03
# 4      520013                          M     3       1       04       03
# ...       ...      ...      ...      ...   ...     ...      ...      ...
# 2939   522205                          M     3       3       04       03
# 2940   522205                          M     3       3       04       03
# 2941   522220                          M     3       3       04       03
# 2942   522220                          M     3       3       04       03
# 2943   522220                          M     3       3       04       03
#
#      TP_UNID TP_LEITO  QT_EXIST  QT_CONTR  QT_SUS   ano mes   index
# 0         15        2         9         0       9  2019  12       0
# 1         05        2         2         0       2  2019  12       1
# 2         05        1         2         0       1  2019  12       2
# 3         05        4         1         0       1  2019  12       3
# 4         05        6         4         0       3  2019  12       4
# ...      ...      ...       ...       ...     ...   ...  ..     ...
# 2939      05        1         3         0       3  2022  11  106221
# 2940      05        4         3         0       3  2022  11  106222
# 2941      05        2         7         0       7  2022  11  106223
# 2942      05        4         2         0       2  2022  11  106224
# 2943      05        5         4         0       4  2022  11  106225
#
# [106226 rows x 16 columns]

# %% [markdown]
# **Fazendo as tratativas individuais nas colunas**

# %%
df_main.MICR_REG.value_counts()
# Out:
#           100634
# SUL         2632
# SUDEST      1401
# 00           545
# 04           324
# 0004         216
# SUDOES       186
# CENTRO       144
# NORTE        144
# Name: MICR_REG, dtype: int64

# %%
# Verificando registros vazios, podemos defini-los como não listados
new_val = []
for mr in df_main.MICR_REG.values:
    if mr == '' or mr == ' ':
        new_val.append('NÃO LISTADO')
    else:
        new_val.append(mr)
df_main['MICR_REG'] = new_val

# %%
df_main.DISTRADM.value_counts()
# Out:
#         105089
# 00         545
# 04         324
# 0004       216
# HOSP        52
# Name: DISTRADM, dtype: int64

# %%
# Verificando registros vazios, podemos defini-los como não listados
new_val = []
for da in df_main.DISTRADM.values:
    if da == '' or da == ' ':
        new_val.append('NÃO LISTADO')
    else:
        new_val.append(da)
df_main['DISTRADM'] = new_val

# %%
# Decodificando o tipo de pessoa de acordo com o dicionário dos dados oficial (física ou jurídica)
new_val = []
for pfpj in df_main.PF_PJ.values:
    if pfpj == '1':
        new_val.append('PESSOA FÍSICA')
    else: 
        new_val.append('PESSOA JURÍDICA')
df_main['PF_PJ'] = new_val

# %%
# Decodificando nível da dependência acordo com o dicionário dos dados oficial (individual ou mantida)
new_val = []
for dep in df_main.NIV_DEP.values:
    if dep == '1':
        new_val.append('INDIVIDUAL')
    else: 
        new_val.append('MANTIDA')
df_main['NIV_DEP'] = new_val

# %%
df_main.CLIENTEL.value_counts()
# Out:
# 03    82977
# 01    18963
# 02     3718
#         568
# Name: CLIENTEL, dtype: int64

# %%
# Verificando registros vazios, podemos defini-los como não listados
new_val = []
for clt in df_main.CLIENTEL.values:
    if clt == '' or clt == ' ':
        new_val.append('NÃO LISTADO')
    else:
        new_val.append(clt)
df_main['CLIENTEL'] = new_val

# %%
df_main.head() # confirmando as alterações
# Out:
#   CODUFMUN     MICR_REG     DISTRADM TPGESTAO            PF_PJ     NIV_DEP  \
# 0   520010  NÃO LISTADO  NÃO LISTADO        M  PESSOA JURÍDICA     MANTIDA
# 1   520013  NÃO LISTADO  NÃO LISTADO        M  PESSOA JURÍDICA  INDIVIDUAL
# 2   520013  NÃO LISTADO  NÃO LISTADO        M  PESSOA JURÍDICA  INDIVIDUAL
# 3   520013  NÃO LISTADO  NÃO LISTADO        M  PESSOA JURÍDICA  INDIVIDUAL
# 4   520013  NÃO LISTADO  NÃO LISTADO        M  PESSOA JURÍDICA  INDIVIDUAL
#
#   ATIVIDAD CLIENTEL TP_UNID TP_LEITO  QT_EXIST  QT_CONTR  QT_SUS   ano mes  \
# 0       04       03      15        2         9         0       9  2019  12
# 1       04       03      05        2         2         0       2  2019  12
# 2       04       03      05        1         2         0       1  2019  12
# 3       04       03      05        4         1         0       1  2019  12
# 4       04       03      05        6         4         0       3  2019  12
#
#    index
# 0      0
# 1      1
# 2      2
# 3      3
# 4      4

# %% [markdown]
# * **Verificando os dtypes e contagem de NaN (nulos)**

# %%
# alterando os dtypes
df_main = df_main.astype({
    'CODUFMUN':'string',
    'MICR_REG':'string',
    'DISTRADM':'string',
    'TPGESTAO':'string',
    'PF_PJ':'string',
    'NIV_DEP':'string',
    'ATIVIDAD':'string',
    'CLIENTEL':'string',
    'TP_UNID':'string',
    'TP_LEITO':'string',
    'QT_EXIST':'int32',
    'QT_CONTR':'int32',
    'QT_SUS':'int32',
    'ano':'string',
    'mes':'string'
})

# informação detalhada dos campos com a contagem de nulos
df_main.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 106226 entries, 0 to 2943
# Data columns (total 16 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   CODUFMUN  106226 non-null  string
#  1   MICR_REG  106226 non-null  string
#  2   DISTRADM  106226 non-null  string
#  3   TPGESTAO  106226 non-null  string
#  4   PF_PJ     106226 non-null  string
#  5   NIV_DEP   106226 non-null  string
#  6   ATIVIDAD  106226 non-null  string
#  7   CLIENTEL  106226 non-null  string
#  8   TP_UNID   106226 non-null  string
#  9   TP_LEITO  106226 non-null  string
#  10  QT_EXIST  106226 non-null  int32
#  11  QT_CONTR  106226 non-null  int32
#  12  QT_SUS    106226 non-null  int32
#  13  ano       106226 non-null  string
#  14  mes       106226 non-null  string
#  15  index     106226 non-null  int64
# dtypes: int32(3), int64(1), string(12)
# memory usage: 12.6 MB

# %% [markdown]
# ---

# %% [markdown]
# # 3. Base de dados secundária (listagem de municípios de GO)
#
# * **Disponível em: https://www.ibge.gov.br/explica/codigos-dos-municipios.php**

# %%
# carregando os dados e alterando os dtypes
df_municipios=pd.read_csv(
    'RELATORIO_DTB_BRASIL_MUNICIPIO.csv').astype({
    'UF':'string',
    'Nome_UF':'string',
    'Regiao_Geografica_Imediata':'string',
    'Nome_Mesorregiao':'string',
    'Nome_Microrregiao':'string',
    'Nome_Municipio':'string'
})

# Filtragem apenas dos municípios de Goiás e redução das colunas
df_municipios = df_municipios.loc[df_municipios['UF']=='52'][[
    'UF','Nome_UF','Regiao_Geografica_Imediata',
    'Nome_Mesorregiao','Nome_Microrregiao','Nome_Municipio']] 
df_municipios
# Out:
#       UF Nome_UF Regiao_Geografica_Imediata Nome_Mesorregiao  \
# 5323  52   Goiás                     520001    Centro Goiano
# 5324  52   Goiás                     520002     Leste Goiano
# 5325  52   Goiás                     520015       Sul Goiano
# 5326  52   Goiás                     520003    Centro Goiano
# 5327  52   Goiás                     520022     Leste Goiano
# ...   ..     ...                        ...              ...
# 5564  52   Goiás                     520001       Sul Goiano
# 5565  52   Goiás                     520002       Sul Goiano
# 5566  52   Goiás                     520009       Sul Goiano
# 5567  52   Goiás                     520022     Leste Goiano
# 5568  52   Goiás                     520018     Leste Goiano
#
#          Nome_Microrregiao      Nome_Municipio
# 5323               Goiânia     Abadia de Goiás
# 5324   Entorno de Brasília           Abadiânia
# 5325  Vale do Rio dos Bois             Acreúna
# 5326               Anicuns           Adelândia
# 5327   Entorno de Brasília  Água Fria de Goiás
# ...                    ...                 ...
# 5564  Vale do Rio dos Bois              Varjão
# 5565          Pires do Rio          Vianópolis
# 5566            Meia Ponte      Vicentinópolis
# 5567   Entorno de Brasília            Vila Boa
# 5568   Entorno de Brasília       Vila Propício
#
# [246 rows x 6 columns]

# %%
df_municipios.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 246 entries, 5323 to 5568
# Data columns (total 6 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   UF                          246 non-null    string
#  1   Nome_UF                     246 non-null    string
#  2   Regiao_Geografica_Imediata  246 non-null    string
#  3   Nome_Mesorregiao            246 non-null    string
#  4   Nome_Microrregiao           246 non-null    string
#  5   Nome_Municipio              246 non-null    string
# dtypes: string(6)
# memory usage: 13.5 KB

# %% [markdown]
# **Para que possamos relacionar as duas tabelas (leitos e municípios), afim de enriquecer nossas análises geográficas, iremos utilizar uma consulta via SQL para facilitar essa tratativa**

# %%
query = """
        SELECT 
               df_main.*,
               CASE
                   WHEN df_municipios.Nome_Mesorregiao ISNULL THEN 'NÃO LISTADO'
                   ELSE df_municipios.Nome_Mesorregiao
               END AS Nome_Mesorregiao,
               CASE
                   WHEN df_municipios.Nome_Microrregiao ISNULL THEN 'NÃO LISTADO'
                   ELSE df_municipios.Nome_Microrregiao
               END AS Nome_Microrregiao,
               CASE
                   WHEN df_municipios.Nome_Municipio ISNULL THEN 'NÃO LISTADO'
                   ELSE df_municipios.Nome_Municipio
               END AS Nome_Municipio
        FROM df_main 
        LEFT JOIN df_municipios ON df_municipios.Regiao_Geografica_Imediata = df_main.CODUFMUN
        """
df_joined = pd.DataFrame(ps.sqldf(query,locals())).drop_duplicates(["index"])
df_joined
# Out:
#        CODUFMUN     MICR_REG     DISTRADM TPGESTAO            PF_PJ  \
# 0        520010  NÃO LISTADO  NÃO LISTADO        M  PESSOA JURÍDICA
# 14       520013  NÃO LISTADO  NÃO LISTADO        M  PESSOA JURÍDICA
# 23       520013  NÃO LISTADO  NÃO LISTADO        M  PESSOA JURÍDICA
# 32       520013  NÃO LISTADO  NÃO LISTADO        M  PESSOA JURÍDICA
# 41       520013  NÃO LISTADO  NÃO LISTADO        M  PESSOA JURÍDICA
# ...         ...          ...          ...      ...              ...
# 111207   522205  NÃO LISTADO  NÃO LISTADO        M  PESSOA JURÍDICA
# 111208   522205  NÃO LISTADO  NÃO LISTADO        M  PESSOA JURÍDICA
# 111209   522220  NÃO LISTADO  NÃO LISTADO        M  PESSOA JURÍDICA
# 111210   522220  NÃO LISTADO  NÃO LISTADO        M  PESSOA JURÍDICA
# 111211   522220  NÃO LISTADO  NÃO LISTADO        M  PESSOA JURÍDICA
#
#            NIV_DEP ATIVIDAD CLIENTEL TP_UNID TP_LEITO  QT_EXIST  QT_CONTR  \
# 0          MANTIDA       04       03      15        2         9         0
# 14      INDIVIDUAL       04       03      05        2         2         0
# 23      INDIVIDUAL       04       03      05        1         2         0
# 32      INDIVIDUAL       04       03      05        4         1         0
# 41      INDIVIDUAL       04       03      05        6         4         0
# ...            ...      ...      ...     ...      ...       ...       ...
# 111207     MANTIDA       04       03      05        1         3         0
# 111208     MANTIDA       04       03      05        4         3         0
# 111209     MANTIDA       04       03      05        2         7         0
# 111210     MANTIDA       04       03      05        4         2         0
# 111211     MANTIDA       04       03      05        5         4         0
#
#         QT_SUS   ano mes   index Nome_Mesorregiao Nome_Microrregiao  \
# 0            9  2019  12       0       Sul Goiano        Meia Ponte
# 14           2  2019  12       1    Centro Goiano           Anicuns
# 23           1  2019  12       2    Centro Goiano           Anicuns
# 32           1  2019  12       3    Centro Goiano           Anicuns
# 41           3  2019  12       4    Centro Goiano           Anicuns
# ...        ...   ...  ..     ...              ...               ...
# 111207       3  2022  11  106221      NÃO LISTADO       NÃO LISTADO
# 111208       3  2022  11  106222      NÃO LISTADO       NÃO LISTADO
# 111209       7  2022  11  106223      NÃO LISTADO       NÃO LISTADO
# 111210       2  2022  11  106224      NÃO LISTADO       NÃO LISTADO
# 111211       4  2022  11  106225      NÃO LISTADO       NÃO LISTADO
#
#        Nome_Municipio
# 0           Porteirão
# 14         Aurilândia
# 23         Aurilândia
# 32         Aurilândia
# 41         Aurilândia
# ...               ...
# 111207    NÃO LISTADO
# 111208    NÃO LISTADO
# 111209    NÃO LISTADO
# 111210    NÃO LISTADO
# 111211    NÃO LISTADO
#
# [106226 rows x 19 columns]

# %%
df_joined.MICR_REG.value_counts()
# Out:
# NÃO LISTADO    100634
# SUL              2632
# SUDEST           1401
# 00                545
# 04                324
# 0004              216
# SUDOES            186
# CENTRO            144
# NORTE             144
# Name: MICR_REG, dtype: int64

# %%
df_joined.Nome_Microrregiao.value_counts()
# Out:
# NÃO LISTADO    105632
# Anicuns           504
# Ceres              54
# Meia Ponte         36
# Name: Nome_Microrregiao, dtype: int64

# %% [markdown]
# **Podemos observar que existem dois campos para uma mesma informação, e que ambos possuem dados como sendo do tipo "NÃO LISTADO". Para sintetizar e deixar essa métrica mais acessível para as próximas etapas, iremos fazer uma tratativa como segue**

# %%
new_val = []
for mr1,mr2 in zip(df_joined.MICR_REG.values,df_joined.Nome_Microrregiao.values):
    if mr1 != 'NÃO LISTADO' and mr2 == 'NÃO LISTADO':
        new_val.append(mr1)
    elif mr1 == 'NÃO LISTADO' and mr2 != 'NÃO LISTADO':
        new_val.append(mr2)
    else:
        new_val.append('NÃO LISTADO')

# %%
df_sintetizado = pd.DataFrame({
    'ANO':df_joined.ano,'MES':df_joined.mes,
    'MESO_REG':df_joined.Nome_Mesorregiao,'MICR_REG':new_val,'MUNICIPIO':df_joined.Nome_Municipio,
    'DISTRADM':df_joined.DISTRADM,'TPGESTAO':df_joined.TPGESTAO,'PF_PJ':df_joined.PF_PJ,
    'NIV_DEP':df_joined.NIV_DEP,'ATIVIDAD':df_joined.ATIVIDAD,'CLIENTEL':df_joined.CLIENTEL,
    'TP_LEITO':df_joined.TP_LEITO,'QT_EXIST':df_joined.QT_EXIST,
    'QT_CONTR':df_joined.QT_CONTR,'QT_SUS':df_joined.QT_SUS
}).astype({
    'ANO':'string','MES':'string','MESO_REG':'string','MICR_REG':'string','MUNICIPIO':'string',
    'DISTRADM':'category','TPGESTAO':'category','PF_PJ':'category','NIV_DEP':'category','ATIVIDAD':'category',
    'CLIENTEL':'category','TP_LEITO':'category','QT_EXIST':'int32','QT_CONTR':'int32','QT_SUS':'int32'
})
df_sintetizado
# Out:
#          ANO MES       MESO_REG     MICR_REG    MUNICIPIO     DISTRADM  \
# 0       2019  12     Sul Goiano   Meia Ponte    Porteirão  NÃO LISTADO
# 14      2019  12  Centro Goiano      Anicuns   Aurilândia  NÃO LISTADO
# 23      2019  12  Centro Goiano      Anicuns   Aurilândia  NÃO LISTADO
# 32      2019  12  Centro Goiano      Anicuns   Aurilândia  NÃO LISTADO
# 41      2019  12  Centro Goiano      Anicuns   Aurilândia  NÃO LISTADO
# ...      ...  ..            ...          ...          ...          ...
# 111207  2022  11    NÃO LISTADO  NÃO LISTADO  NÃO LISTADO  NÃO LISTADO
# 111208  2022  11    NÃO LISTADO  NÃO LISTADO  NÃO LISTADO  NÃO LISTADO
# 111209  2022  11    NÃO LISTADO  NÃO LISTADO  NÃO LISTADO  NÃO LISTADO
# 111210  2022  11    NÃO LISTADO  NÃO LISTADO  NÃO LISTADO  NÃO LISTADO
# 111211  2022  11    NÃO LISTADO  NÃO LISTADO  NÃO LISTADO  NÃO LISTADO
#
#        TPGESTAO            PF_PJ     NIV_DEP ATIVIDAD CLIENTEL TP_LEITO  \
# 0             M  PESSOA JURÍDICA     MANTIDA       04       03        2
# 14            M  PESSOA JURÍDICA  INDIVIDUAL       04       03        2
# 23            M  PESSOA JURÍDICA  INDIVIDUAL       04       03        1
# 32            M  PESSOA JURÍDICA  INDIVIDUAL       04       03        4
# 41            M  PESSOA JURÍDICA  INDIVIDUAL       04       03        6
# ...         ...              ...         ...      ...      ...      ...
# 111207        M  PESSOA JURÍDICA     MANTIDA       04       03        1
# 111208        M  PESSOA JURÍDICA     MANTIDA       04       03        4
# 111209        M  PESSOA JURÍDICA     MANTIDA       04       03        2
# 111210        M  PESSOA JURÍDICA     MANTIDA       04       03        4
# 111211        M  PESSOA JURÍDICA     MANTIDA       04       03        5
#
#         QT_EXIST  QT_CONTR  QT_SUS
# 0              9         0       9
# 14             2         0       2
# 23             2         0       1
# 32             1         0       1
# 41             4         0       3
# ...          ...       ...     ...
# 111207         3         0       3
# 111208         3         0       3
# 111209         7         0       7
# 111210         2         0       2
# 111211         4         0       4
#
# [106226 rows x 15 columns]

# %% [markdown]
# **Este é nosso dataframe final que deverá ser utilizado na etapa de análise exploratória.**

# %% [markdown]
# ---

# %% [markdown]
# # 4. Análise Exploratória dos Dados

# %% [markdown]
# ## (i) Interpretação estatística geral:
#
# **Para a compreensão estatística dos nossos dados, iremos nesta etapa observar apenas as variáveis quantitativas, pois são estritamente numéricas**

# %% [markdown]
# ### >> Distribuição Geral

# %%
df_sintetizado.describe(percentiles=[.001,.01,.1,.25,.5,.75,.9,.99,.999])
# Out:
#             QT_EXIST  QT_CONTR         QT_SUS
# count  106226.000000  106226.0  106226.000000
# mean        7.259983       0.0       4.363009
# std        15.008795       0.0      11.488814
# min         0.000000       0.0       0.000000
# 0.1%        1.000000       0.0       0.000000
# 1%          1.000000       0.0       0.000000
# 10%         1.000000       0.0       0.000000
# 25%         2.000000       0.0       0.000000
# 50%         4.000000       0.0       1.000000
# 75%         8.000000       0.0       4.000000
# 90%        15.000000       0.0      10.000000
# 99%        65.000000       0.0      48.000000
# 99.9%     200.000000       0.0     160.000000
# max       343.000000       0.0     275.000000

# %% [markdown]
# **Do resultado mostrado acima, podemos observar:**
# * **QT_EXIST: apresenta dados bem próximos até o percentil de 75%, aproximadamente. Após essa divisão, podemos observar grandes saltos de valores, o que pode indicar presença de outliers na distribuição.**
# * **QT_CONTR: apresenta um total de 0 registros durante todo o histórico analisado. Esta variável em específico não será considerada nas análises posteriores.**
# * **QT_SUS: da mesma forma que ocorreu com QT_EXIST, até o percentil de 75% os valores estão relativamente próximos uns dos outros. Após essa divisão começamos a notar saltos de valores, uma possível evidência de outliers.**

# %% [markdown]
# ### >> Histogramas, Curvas de Densidade e Box-Plot

# %% [markdown]
# #### Geral

# %%
cols = ['QT_EXIST','QT_SUS']
for c in cols:
    plt.figure(figsize=(15,5))
    sns.distplot(df_sintetizado[c],rug=True)
# Out:
# /tmp/ipykernel_16229/1776926402.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df_sintetizado[c],rug=True)
# /tmp/ipykernel_16229/1776926402.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df_sintetizado[c],rug=True)

# %% [markdown]
# **Os resultados mostrados acima para as distribuições de densidade e histogramas de QT_EXIST e QT_SUS revelam curvas do tipo *"right skewed"*. Podemos observar certos gaps nos intervalos, isto é, como suspeitado anteriormente pela tabela dos percentis existem saltos nas contagens de leitos, o que é novamente um forte indício de outliers. Apesar de não termos ainda uma análise explícita no tempo, podemos suspeitar que esses outliers sejam referentes aos meses de maior gravidade da pandemia, em que a demanda por leitos aumentou gradativamente.
# Podemos estender essas análises de distribuição partindo diretamente para o Boxplot, que é mais intuitivo para a identificação de outliers.**

# %% [markdown]
# #### Quantidade de Leitos Existentes (QT_EXIST)

# %%
plt.figure(figsize=(15,5))
sns.boxplot(data=df_sintetizado, x="QT_EXIST", y="NIV_DEP", hue="TPGESTAO")
# Out:
# <AxesSubplot: xlabel='QT_EXIST', ylabel='NIV_DEP'>

# %% [markdown]
# #### Quantidade de Leitos Contratados (QT_SUS)

# %%
plt.figure(figsize=(15,5))
sns.boxplot(data=df_sintetizado, x="QT_SUS", y="NIV_DEP", hue="TPGESTAO")
# Out:
# <AxesSubplot: xlabel='QT_SUS', ylabel='NIV_DEP'>

# %% [markdown]
# **Dos boxplots apresentados anteriormente podemos observar que existe a grande concentração de outliers como suspeitado inicialmente. A análise foi feita pelo agrupamento do nível de dependência (representado pelo eixo y do gráfico) e a coloração indica o tipo da gestão. Com relação à gestão, apenas a do tipo D se manteve bastante limitada no domínio de QT_EXIST e QT_SUS, inclusive sem outliers (essa gestão ficou restrita ao nível individual de dependência). Para as duas outras gestões (E,M), podemos observar grande representatividade tanto na dependência individual, quanto na dependência mantida. Essas gestões são as que mais impactaram no surgimento de outliers para as duas variáveis quantitativas em análise. Novamente não temos ainda uma conclusão explícita desses saltos de quantidade de leitos no tempo, mas isso deve ser retomado nas análises posteriores com mais detalhes.**

# %% [markdown]
# ## (ii) Correlação Numérica (Pearson) e Dispersão Quantitativa

# %%
plt.figure(figsize=(6,4))
sns.heatmap(df_sintetizado.drop(['QT_CONTR'], axis=1).corr(), annot=False, cmap='viridis')
# Out:
# <AxesSubplot: >

# %%
sns.scatterplot(data=df_sintetizado, x="QT_SUS", y="QT_EXIST", hue="TPGESTAO", size="NIV_DEP")
# Out:
# <AxesSubplot: xlabel='QT_SUS', ylabel='QT_EXIST'>

# %% [markdown]
# **A matriz de correlação apresentada (analisada estritamente para as variáveis numéricas quantitativas QT_EXIST e QT_SUS, neste caso) revela que existe uma correlação relativamente alta, sendo σ≈0.84. Isso pode ainda ser complementado pelo gráfico de dispersão para as duas variáveis, em que percebe-se uma tendência de variação linear diretamente proporcional (ao passo que uma aumenta, a outra tende a acompanhar), sobretudo nos cenários de um tipo de gestão "E" para nível de dependência mantida.**

# %% [markdown]
# ## (iii) Comparação da distribuição geográfica dos leitos por município antes e depois da pandemia
#
# **Nesta etapa, iremos fazer as seguintes considerações:**
# * **Dado o objetivo principal de gerar insights ```durante a pandemia```, a base de dados foi gerada a partir de dez/19 (como mencionado inicialmente neste documento).**
# * **O atual cenário ainda permanece como sendo de pandemia, portanto o evento ainda não cessou no momento da elaboração deste documento.**
# * **Considerados os pontos anteriores, iremos assumir como um cenário ```anterior``` à pandemia todos os meses que antecedem a primeira dosagem da vacina no Brasil, datada por volta de jan/21 (https://g1.globo.com/sp/sao-paulo/noticia/2022/01/17/ha-um-ano-sp-vacinava-1a-pessoa-contra-covid-no-brasil-veja-o-que-mudou-e-projecoes-para-o-futuro.ghtml) e contados a partir de dez/19. Da mesma forma, assumiremos como um cenário ```posterior``` à pandemia (de forma simbólica) todos os meses posteriores, contados a partir de jan/21 até o momento.**

# %% [markdown]
# **Antes de analisar de fato as distribuições geográficas dos leitos, vamos observar de uma forma quantitativa a representatividade de cada um dos campos que indicam localidades dos nossos registros obtidos**

# %%
x = df_sintetizado.MESO_REG.value_counts().index
y = df_sintetizado.MESO_REG.value_counts().values

plt.figure(figsize=(15,6))
plt.barh(x,y)
plt.xlabel('Quantidade de Registros')
plt.ylabel('MESO_REG')
for index, value in enumerate(y):
    plt.text(value,index,str(value))

# %%
x = df_sintetizado.MICR_REG.value_counts().index
y = df_sintetizado.MICR_REG.value_counts().values

plt.figure(figsize=(15,6))
plt.barh(x,y)
plt.xlabel('Quantidade de Registros')
plt.ylabel('MICR_REG')
for index, value in enumerate(y):
    plt.text(value,index,str(value))

# %%
x = df_sintetizado.MUNICIPIO.value_counts().index
y = df_sintetizado.MUNICIPIO.value_counts().values

plt.figure(figsize=(15,6))
plt.barh(x,y)
plt.xlabel('Quantidade de Registros')
plt.ylabel('MUNICIPIO')
for index, value in enumerate(y):
    plt.text(value,index,str(value))
