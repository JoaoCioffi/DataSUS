# %% [markdown]
# ![image.png](attachment:image.png)
#
# ---
# **Sugestões de Análise:**
# * **Comparar a distribuição geográfica dos leitos por município antes e depois da pandemia**
# * **Analisar a evolução do número de leitos no tempo**
# * **Verificar se em algum momento pôde ser observado um declínio na capacidade hospitalar instalada**
# * **Comparar a quantidade de leitos SUS e leitos não SUS no tempo e no espaço**

# %% [markdown]
# # 1. Carregando as dependências do projeto

# %%
# sistema
from os import system

# manipulação e tratamento de dados tabulares
import pandas as pd
import pysus.online_data.CNES as CNES

# bibliotecas numéricas
import numpy as np

# bibliotecas de visualização e estatítica
from matplotlib import pyplot as plt
import seaborn as sns

# %% [markdown]
# # 2. Carregando a base de dados
#
# **Tendo o objetivo de realizar uma análise exploratória para descrever a evolução da capacidade hospitalar (número de leitos) durante a pandemia de Covid-19 em Goiás, podemos considerar como período ```dez/2019``` (que foi tido como o primeiro mês do início da pandemia) até ```nov/2022``` (que é o último mês registrado na base de dados original antes da elaboração do presente relatório).**
#
# **Além disso, iremos criar variáveis para representar uma estrutura tabular de dados ("dataframe") seguindo o padrão ```df_mes_ano```, em que:**
# * **mes: 2 dígitos numéricos (01-12), representando o mês a ser utilizado para consulta**
# * **ano: 2 dígitos numéricos, representando os dois últimos digitos do ano a ser utilizado para consulta**

# %%
# Verificando a data atual
system('date')
# Out:
# Wed Dec 28 10:28:05 PM -03 2022
# 0

# %% [markdown]
# **Desta forma, iremos manter o período descrito anteriormente como sendo a filtragem para gerar nossa base de dados. Além disso, vamos criar uma função para facilitar a leitura desses dados.**

# %%
def loadDataSUS(year,month,params={
    'group':'LT',
    'state':'GO'
}):
    df = CNES.download(params['group'],params['state'],year,month)
    df = pd.DataFrame(df) # convertendo em objeto Pandas
    if params['group'] == 'LT':
        # criando novos campos
        df['ano'] = [val.strip()[0:4] for val in df['COMPETEN']]
        df['mes'] = [val.strip()[4:] for val in df['COMPETEN']]
    return df

# %% [markdown]
# ## (i) 2019

# %%
df_12_19 = loadDataSUS(2019,12)
df_12_19
# Out:
# 2022-12-28 22:58:20.545 | DEBUG    | pysus.online_data.CNES:download:64 - Stablishing connection with ftp.datasus.gov.br.
# 220 Microsoft FTP Service
# 2022-12-28 22:58:20.573 | DEBUG    | pysus.online_data.CNES:download:69 - Changing FTP work dir to: dissemin/publicos/CNES/200508_/Dados/LT/
# 2022-12-28 22:58:20.892 | DEBUG    | pysus.online_data.CNES:_fetch_file:99 - LTGO1912.dbc removed.
# 2022-12-28 22:58:20.910 | INFO     | pysus.online_data.CNES:download:83 - Data stored as parquet at /home/noetic-sierra/pysus/CNES_LTGO1912_.parquet
#          CNES CODUFMUN REGSAUDE MICR_REG DISTRSAN DISTRADM TPGESTAO PF_PJ  \
# 0     9331603   520010                                            M     3
# 1     2335506   520013       15                                   M     3
# 2     2335506   520013       15                                   M     3
# 3     2335506   520013       15                                   M     3
# 4     2335506   520013       15                                   M     3
# ...       ...      ...      ...      ...      ...      ...      ...   ...
# 2805  2383691   522205      001                                   M     3
# 2806  2383691   522205      001                                   M     3
# 2807  2439883   522220       02                                   M     3
# 2808  2439883   522220       02                                   M     3
# 2809  2439883   522220       02                                   M     3
#
#             CPF_CNPJ NIV_DEP  ... TP_LEITO CODLEITO QT_EXIST QT_CONTR QT_SUS  \
# 0     00000000000000       3  ...        2       33        9        0      9
# 1     00269860000125       1  ...        2       41        2        0      2
# 2     00269860000125       1  ...        1       03        2        0      1
# 3     00269860000125       1  ...        4       10        1        0      1
# 4     00269860000125       1  ...        6       34        4        0      3
# ...              ...     ...  ...      ...      ...      ...      ...    ...
# 2805  00000000000000       3  ...        4       43        1        0      1
# 2806  00000000000000       3  ...        5       45        3        0      3
# 2807  00000000000000       3  ...        5       45        4        0      4
# 2808  00000000000000       3  ...        2       33        7        0      7
# 2809  00000000000000       3  ...        4       43        2        0      2
#
#      QT_NSUS COMPETEN NAT_JUR   ano mes
# 0          0   201912    1244  2019  12
# 1          0   201912    2062  2019  12
# 2          1   201912    2062  2019  12
# 3          0   201912    2062  2019  12
# 4          1   201912    2062  2019  12
# ...      ...      ...     ...   ...  ..
# 2805       0   201912    1244  2019  12
# 2806       0   201912    1244  2019  12
# 2807       0   201912    1244  2019  12
# 2808       0   201912    1244  2019  12
# 2809       0   201912    1244  2019  12
#
# [2810 rows x 30 columns]

# %% [markdown]
# ## (ii) 2020

# %%
df_01_20 = loadDataSUS(2020,1)
df_02_20 = loadDataSUS(2020,2)
df_03_20 = loadDataSUS(2020,3)
df_04_20 = loadDataSUS(2020,4)
df_05_20 = loadDataSUS(2020,5)
df_06_20 = loadDataSUS(2020,6)
df_07_20 = loadDataSUS(2020,7)
df_08_20 = loadDataSUS(2020,8)
df_09_20 = loadDataSUS(2020,9)
df_10_20 = loadDataSUS(2020,10)
df_11_20 = loadDataSUS(2020,11)
df_12_20 = loadDataSUS(2020,12)
# Out:
# 2022-12-28 22:58:23.224 | DEBUG    | pysus.online_data.CNES:download:64 - Stablishing connection with ftp.datasus.gov.br.
# 220 Microsoft FTP Service
# 2022-12-28 22:58:23.251 | DEBUG    | pysus.online_data.CNES:download:69 - Changing FTP work dir to: dissemin/publicos/CNES/200508_/Dados/LT/
# 2022-12-28 22:58:23.550 | DEBUG    | pysus.online_data.CNES:_fetch_file:99 - LTGO2001.dbc removed.
# 2022-12-28 22:58:23.569 | INFO     | pysus.online_data.CNES:download:83 - Data stored as parquet at /home/noetic-sierra/pysus/CNES_LTGO2001_.parquet
# 2022-12-28 22:58:23.707 | DEBUG    | pysus.online_data.CNES:download:64 - Stablishing connection with ftp.datasus.gov.br.
# 220 Microsoft FTP Service
# 2022-12-28 22:58:23.736 | DEBUG    | pysus.online_data.CNES:download:69 - Changing FTP work dir to: dissemin/publicos/CNES/200508_/Dados/LT/
# 2022-12-28 22:58:24.035 | DEBUG    | pysus.online_data.CNES:_fetch_file:99 - LTGO2002.dbc removed.
# 2022-12-28 22:58:24.047 | INFO     | pysus.online_data.CNES:download:83 - Data stored as parquet at /home/noetic-sierra/pysus/CNES_LTGO2002_.parquet
# 2022-12-28 22:58:24.176 | DEBUG    | pysus.online_data.CNES:download:64 - Stablishing connection with ftp.datasus.gov.br.
# 220 Microsoft FTP Service
# 2022-12-28 22:58:24.205 | DEBUG    | pysus.online_data.CNES:download:69 - Changing FTP work dir to: dissemin/publicos/CNES/200508_/Dados/LT/
# 2022-12-28 22:58:24.509 | DEBUG    | pysus.online_data.CNES:_fetch_file:99 - LTGO2003.dbc removed.
# 2022-12-28 22:58:24.521 | INFO     | pysus.online_data.CNES:download:83 - Data stored as parquet at /home/noetic-sierra/pysus/CNES_LTGO2003_.parquet
# 2022-12-28 22:58:24.654 | DEBUG    | pysus.online_data.CNES:download:64 - Stablishing connection with ftp.datasus.gov.br.
# 220 Microsoft FTP Service
# 2022-12-28 22:58:24.682 | DEBUG    | pysus.online_data.CNES:download:69 - Changing FTP work dir to: dissemin/publicos/CNES/200508_/Dados/LT/
# 2022-12-28 22:58:24.981 | DEBUG    | pysus.online_data.CNES:_fetch_file:99 - LTGO2004.dbc removed.
# 2022-12-28 22:58:25.000 | INFO     | pysus.online_data.CNES:download:83 - Data stored as parquet at /home/noetic-sierra/pysus/CNES_LTGO2004_.parquet
# 2022-12-28 22:58:25.134 | DEBUG    | pysus.online_data.CNES:download:64 - Stablishing connection with ftp.datasus.gov.br.
# 220 Microsoft FTP Service
# 2022-12-28 22:58:25.161 | DEBUG    | pysus.online_data.CNES:download:69 - Changing FTP work dir to: dissemin/publicos/CNES/200508_/Dados/LT/
# 2022-12-28 22:58:25.454 | DEBUG    | pysus.online_data.CNES:_fetch_file:99 - LTGO2005.dbc removed.
# 2022-12-28 22:58:25.467 | INFO     | pysus.online_data.CNES:download:83 - Data stored as parquet at /home/noetic-sierra/pysus/CNES_LTGO2005_.parquet
# 2022-12-28 22:58:25.583 | DEBUG    | pysus.online_data.CNES:download:64 - Stablishing connection with ftp.datasus.gov.br.
# 220 Microsoft FTP Service
# 2022-12-28 22:58:25.609 | DEBUG    | pysus.online_data.CNES:download:69 - Changing FTP work dir to: dissemin/publicos/CNES/200508_/Dados/LT/
# 2022-12-28 22:58:25.912 | DEBUG    | pysus.online_data.CNES:_fetch_file:99 - LTGO2006.dbc removed.
# 2022-12-28 22:58:25.928 | INFO     | pysus.online_data.CNES:download:83 - Data stored as parquet at /home/noetic-sierra/pysus/CNES_LTGO2006_.parquet
# 2022-12-28 22:58:26.037 | DEBUG    | pysus.online_data.CNES:download:64 - Stablishing connection with ftp.datasus.gov.br.
# 220 Microsoft FTP Service
# 2022-12-28 22:58:26.065 | DEBUG    | pysus.online_data.CNES:download:69 - Changing FTP work dir to: dissemin/publicos/CNES/200508_/Dados/LT/
# 2022-12-28 22:58:26.365 | DEBUG    | pysus.online_data.CNES:_fetch_file:99 - LTGO2007.dbc removed.
# 2022-12-28 22:58:26.385 | INFO     | pysus.online_data.CNES:download:83 - Data stored as parquet at /home/noetic-sierra/pysus/CNES_LTGO2007_.parquet
# 2022-12-28 22:58:26.526 | DEBUG    | pysus.online_data.CNES:download:64 - Stablishing connection with ftp.datasus.gov.br.
# 220 Microsoft FTP Service
# 2022-12-28 22:58:26.553 | DEBUG    | pysus.online_data.CNES:download:69 - Changing FTP work dir to: dissemin/publicos/CNES/200508_/Dados/LT/
# 2022-12-28 22:58:26.850 | DEBUG    | pysus.online_data.CNES:_fetch_file:99 - LTGO2008.dbc removed.
# 2022-12-28 22:58:26.863 | INFO     | pysus.online_data.CNES:download:83 - Data stored as parquet at /home/noetic-sierra/pysus/CNES_LTGO2008_.parquet
# 2022-12-28 22:58:26.976 | DEBUG    | pysus.online_data.CNES:download:64 - Stablishing connection with ftp.datasus.gov.br.
# 220 Microsoft FTP Service
# 2022-12-28 22:58:27.005 | DEBUG    | pysus.online_data.CNES:download:69 - Changing FTP work dir to: dissemin/publicos/CNES/200508_/Dados/LT/
# 2022-12-28 22:58:27.281 | DEBUG    | pysus.online_data.CNES:_fetch_file:99 - LTGO2009.dbc removed.
# 2022-12-28 22:58:27.293 | INFO     | pysus.online_data.CNES:download:83 - Data stored as parquet at /home/noetic-sierra/pysus/CNES_LTGO2009_.parquet
# 2022-12-28 22:58:27.405 | DEBUG    | pysus.online_data.CNES:download:64 - Stablishing connection with ftp.datasus.gov.br.
# 220 Microsoft FTP Service
# 2022-12-28 22:58:27.433 | DEBUG    | pysus.online_data.CNES:download:69 - Changing FTP work dir to: dissemin/publicos/CNES/200508_/Dados/LT/
# 2022-12-28 22:58:27.721 | DEBUG    | pysus.online_data.CNES:_fetch_file:99 - LTGO2010.dbc removed.
# 2022-12-28 22:58:27.736 | INFO     | pysus.online_data.CNES:download:83 - Data stored as parquet at /home/noetic-sierra/pysus/CNES_LTGO2010_.parquet
# 2022-12-28 22:58:27.847 | DEBUG    | pysus.online_data.CNES:download:64 - Stablishing connection with ftp.datasus.gov.br.
# 220 Microsoft FTP Service
# 2022-12-28 22:58:27.873 | DEBUG    | pysus.online_data.CNES:download:69 - Changing FTP work dir to: dissemin/publicos/CNES/200508_/Dados/LT/
# 2022-12-28 22:58:28.167 | DEBUG    | pysus.online_data.CNES:_fetch_file:99 - LTGO2011.dbc removed.
# 2022-12-28 22:58:28.180 | INFO     | pysus.online_data.CNES:download:83 - Data stored as parquet at /home/noetic-sierra/pysus/CNES_LTGO2011_.parquet
# 2022-12-28 22:58:28.293 | DEBUG    | pysus.online_data.CNES:download:64 - Stablishing connection with ftp.datasus.gov.br.
# 220 Microsoft FTP Service
# 2022-12-28 22:58:28.322 | DEBUG    | pysus.online_data.CNES:download:69 - Changing FTP work dir to: dissemin/publicos/CNES/200508_/Dados/LT/
# 2022-12-28 22:58:28.594 | DEBUG    | pysus.online_data.CNES:_fetch_file:99 - LTGO2012.dbc removed.
# 2022-12-28 22:58:28.607 | INFO     | pysus.online_data.CNES:download:83 - Data stored as parquet at /home/noetic-sierra/pysus/CNES_LTGO2012_.parquet

# %% [markdown]
# ## (iii) 2021

# %%
df_01_21 = loadDataSUS(2021,1)
df_02_21 = loadDataSUS(2021,2)
df_03_21 = loadDataSUS(2021,3)
df_04_21 = loadDataSUS(2021,4)
df_05_21 = loadDataSUS(2021,5)
df_06_21 = loadDataSUS(2021,6)
df_07_21 = loadDataSUS(2021,7)
df_08_21 = loadDataSUS(2021,8)
df_09_21 = loadDataSUS(2021,9)
df_10_21 = loadDataSUS(2021,10)
df_11_21 = loadDataSUS(2021,11)
df_12_21 = loadDataSUS(2021,12)
# Out:
# 2022-12-28 22:58:28.726 | DEBUG    | pysus.online_data.CNES:download:64 - Stablishing connection with ftp.datasus.gov.br.
# 220 Microsoft FTP Service
# 2022-12-28 22:58:28.754 | DEBUG    | pysus.online_data.CNES:download:69 - Changing FTP work dir to: dissemin/publicos/CNES/200508_/Dados/LT/
# 2022-12-28 22:58:29.044 | DEBUG    | pysus.online_data.CNES:_fetch_file:99 - LTGO2101.dbc removed.
# 2022-12-28 22:58:29.057 | INFO     | pysus.online_data.CNES:download:83 - Data stored as parquet at /home/noetic-sierra/pysus/CNES_LTGO2101_.parquet
# 2022-12-28 22:58:29.170 | DEBUG    | pysus.online_data.CNES:download:64 - Stablishing connection with ftp.datasus.gov.br.
# 220 Microsoft FTP Service
# 2022-12-28 22:58:29.198 | DEBUG    | pysus.online_data.CNES:download:69 - Changing FTP work dir to: dissemin/publicos/CNES/200508_/Dados/LT/
# 2022-12-28 22:58:29.501 | DEBUG    | pysus.online_data.CNES:_fetch_file:99 - LTGO2102.dbc removed.
# 2022-12-28 22:58:29.514 | INFO     | pysus.online_data.CNES:download:83 - Data stored as parquet at /home/noetic-sierra/pysus/CNES_LTGO2102_.parquet
# 2022-12-28 22:58:29.623 | DEBUG    | pysus.online_data.CNES:download:64 - Stablishing connection with ftp.datasus.gov.br.
# 220 Microsoft FTP Service
# 2022-12-28 22:58:29.651 | DEBUG    | pysus.online_data.CNES:download:69 - Changing FTP work dir to: dissemin/publicos/CNES/200508_/Dados/LT/
# 2022-12-28 22:58:29.948 | DEBUG    | pysus.online_data.CNES:_fetch_file:99 - LTGO2103.dbc removed.
# 2022-12-28 22:58:29.968 | INFO     | pysus.online_data.CNES:download:83 - Data stored as parquet at /home/noetic-sierra/pysus/CNES_LTGO2103_.parquet
# 2022-12-28 22:58:30.081 | DEBUG    | pysus.online_data.CNES:download:64 - Stablishing connection with ftp.datasus.gov.br.
# 220 Microsoft FTP Service
# 2022-12-28 22:58:30.109 | DEBUG    | pysus.online_data.CNES:download:69 - Changing FTP work dir to: dissemin/publicos/CNES/200508_/Dados/LT/
# 2022-12-28 22:58:30.430 | DEBUG    | pysus.online_data.CNES:_fetch_file:99 - LTGO2104.dbc removed.
# 2022-12-28 22:58:30.453 | INFO     | pysus.online_data.CNES:download:83 - Data stored as parquet at /home/noetic-sierra/pysus/CNES_LTGO2104_.parquet
# 2022-12-28 22:58:30.566 | DEBUG    | pysus.online_data.CNES:download:64 - Stablishing connection with ftp.datasus.gov.br.
# 220 Microsoft FTP Service
# 2022-12-28 22:58:30.593 | DEBUG    | pysus.online_data.CNES:download:69 - Changing FTP work dir to: dissemin/publicos/CNES/200508_/Dados/LT/
# 2022-12-28 22:58:30.891 | DEBUG    | pysus.online_data.CNES:_fetch_file:99 - LTGO2105.dbc removed.
# 2022-12-28 22:58:30.903 | INFO     | pysus.online_data.CNES:download:83 - Data stored as parquet at /home/noetic-sierra/pysus/CNES_LTGO2105_.parquet
# 2022-12-28 22:58:31.025 | DEBUG    | pysus.online_data.CNES:download:64 - Stablishing connection with ftp.datasus.gov.br.
# 220 Microsoft FTP Service
# 2022-12-28 22:58:31.054 | DEBUG    | pysus.online_data.CNES:download:69 - Changing FTP work dir to: dissemin/publicos/CNES/200508_/Dados/LT/
# 2022-12-28 22:58:31.455 | DEBUG    | pysus.online_data.CNES:_fetch_file:99 - LTGO2106.dbc removed.
# 2022-12-28 22:58:31.474 | INFO     | pysus.online_data.CNES:download:83 - Data stored as parquet at /home/noetic-sierra/pysus/CNES_LTGO2106_.parquet
# 2022-12-28 22:58:31.599 | DEBUG    | pysus.online_data.CNES:download:64 - Stablishing connection with ftp.datasus.gov.br.
# 220 Microsoft FTP Service
# 2022-12-28 22:58:31.627 | DEBUG    | pysus.online_data.CNES:download:69 - Changing FTP work dir to: dissemin/publicos/CNES/200508_/Dados/LT/
# 2022-12-28 22:58:31.978 | DEBUG    | pysus.online_data.CNES:_fetch_file:99 - LTGO2107.dbc removed.
# 2022-12-28 22:58:31.990 | INFO     | pysus.online_data.CNES:download:83 - Data stored as parquet at /home/noetic-sierra/pysus/CNES_LTGO2107_.parquet
# 2022-12-28 22:58:32.116 | DEBUG    | pysus.online_data.CNES:download:64 - Stablishing connection with ftp.datasus.gov.br.
# 220 Microsoft FTP Service
# 2022-12-28 22:58:32.145 | DEBUG    | pysus.online_data.CNES:download:69 - Changing FTP work dir to: dissemin/publicos/CNES/200508_/Dados/LT/
# 2022-12-28 22:58:32.470 | DEBUG    | pysus.online_data.CNES:_fetch_file:99 - LTGO2108.dbc removed.
# 2022-12-28 22:58:32.490 | INFO     | pysus.online_data.CNES:download:83 - Data stored as parquet at /home/noetic-sierra/pysus/CNES_LTGO2108_.parquet
# 2022-12-28 22:58:32.605 | DEBUG    | pysus.online_data.CNES:download:64 - Stablishing connection with ftp.datasus.gov.br.
# 220 Microsoft FTP Service
# 2022-12-28 22:58:32.633 | DEBUG    | pysus.online_data.CNES:download:69 - Changing FTP work dir to: dissemin/publicos/CNES/200508_/Dados/LT/
# 2022-12-28 22:58:32.967 | DEBUG    | pysus.online_data.CNES:_fetch_file:99 - LTGO2109.dbc removed.
# 2022-12-28 22:58:32.979 | INFO     | pysus.online_data.CNES:download:83 - Data stored as parquet at /home/noetic-sierra/pysus/CNES_LTGO2109_.parquet
# 2022-12-28 22:58:33.094 | DEBUG    | pysus.online_data.CNES:download:64 - Stablishing connection with ftp.datasus.gov.br.
# 220 Microsoft FTP Service
# 2022-12-28 22:58:33.123 | DEBUG    | pysus.online_data.CNES:download:69 - Changing FTP work dir to: dissemin/publicos/CNES/200508_/Dados/LT/
# 2022-12-28 22:58:33.454 | DEBUG    | pysus.online_data.CNES:_fetch_file:99 - LTGO2110.dbc removed.
# 2022-12-28 22:58:33.466 | INFO     | pysus.online_data.CNES:download:83 - Data stored as parquet at /home/noetic-sierra/pysus/CNES_LTGO2110_.parquet
# 2022-12-28 22:58:33.608 | DEBUG    | pysus.online_data.CNES:download:64 - Stablishing connection with ftp.datasus.gov.br.
# 220 Microsoft FTP Service
# 2022-12-28 22:58:33.635 | DEBUG    | pysus.online_data.CNES:download:69 - Changing FTP work dir to: dissemin/publicos/CNES/200508_/Dados/LT/
# 2022-12-28 22:58:33.925 | DEBUG    | pysus.online_data.CNES:_fetch_file:99 - LTGO2111.dbc removed.
# 2022-12-28 22:58:33.939 | INFO     | pysus.online_data.CNES:download:83 - Data stored as parquet at /home/noetic-sierra/pysus/CNES_LTGO2111_.parquet
# 2022-12-28 22:58:34.056 | DEBUG    | pysus.online_data.CNES:download:64 - Stablishing connection with ftp.datasus.gov.br.
# 220 Microsoft FTP Service
# 2022-12-28 22:58:34.084 | DEBUG    | pysus.online_data.CNES:download:69 - Changing FTP work dir to: dissemin/publicos/CNES/200508_/Dados/LT/
# 2022-12-28 22:58:34.384 | DEBUG    | pysus.online_data.CNES:_fetch_file:99 - LTGO2112.dbc removed.
# 2022-12-28 22:58:34.396 | INFO     | pysus.online_data.CNES:download:83 - Data stored as parquet at /home/noetic-sierra/pysus/CNES_LTGO2112_.parquet

# %% [markdown]
# ## (iv) 2022

# %%
df_01_22 = loadDataSUS(2022,1)
df_02_22 = loadDataSUS(2022,2)
df_03_22 = loadDataSUS(2022,3)
df_04_22 = loadDataSUS(2022,4)
df_05_22 = loadDataSUS(2022,5)
df_06_22 = loadDataSUS(2022,6)
df_07_22 = loadDataSUS(2022,7)
df_08_22 = loadDataSUS(2022,8)
df_09_22 = loadDataSUS(2022,9)
df_10_22 = loadDataSUS(2022,10)
df_11_22 = loadDataSUS(2022,11)
# Out:
# 2022-12-28 22:58:34.514 | DEBUG    | pysus.online_data.CNES:download:64 - Stablishing connection with ftp.datasus.gov.br.
# 220 Microsoft FTP Service
# 2022-12-28 22:58:34.541 | DEBUG    | pysus.online_data.CNES:download:69 - Changing FTP work dir to: dissemin/publicos/CNES/200508_/Dados/LT/
# 2022-12-28 22:58:34.862 | DEBUG    | pysus.online_data.CNES:_fetch_file:99 - LTGO2201.dbc removed.
# 2022-12-28 22:58:34.874 | INFO     | pysus.online_data.CNES:download:83 - Data stored as parquet at /home/noetic-sierra/pysus/CNES_LTGO2201_.parquet
# 2022-12-28 22:58:34.984 | DEBUG    | pysus.online_data.CNES:download:64 - Stablishing connection with ftp.datasus.gov.br.
# 220 Microsoft FTP Service
# 2022-12-28 22:58:35.012 | DEBUG    | pysus.online_data.CNES:download:69 - Changing FTP work dir to: dissemin/publicos/CNES/200508_/Dados/LT/
# 2022-12-28 22:58:35.343 | DEBUG    | pysus.online_data.CNES:_fetch_file:99 - LTGO2202.dbc removed.
# 2022-12-28 22:58:35.357 | INFO     | pysus.online_data.CNES:download:83 - Data stored as parquet at /home/noetic-sierra/pysus/CNES_LTGO2202_.parquet
# 2022-12-28 22:58:35.470 | DEBUG    | pysus.online_data.CNES:download:64 - Stablishing connection with ftp.datasus.gov.br.
# 220 Microsoft FTP Service
# 2022-12-28 22:58:35.496 | DEBUG    | pysus.online_data.CNES:download:69 - Changing FTP work dir to: dissemin/publicos/CNES/200508_/Dados/LT/
# 2022-12-28 22:58:35.791 | DEBUG    | pysus.online_data.CNES:_fetch_file:99 - LTGO2203.dbc removed.
# 2022-12-28 22:58:35.806 | INFO     | pysus.online_data.CNES:download:83 - Data stored as parquet at /home/noetic-sierra/pysus/CNES_LTGO2203_.parquet
# 2022-12-28 22:58:35.949 | DEBUG    | pysus.online_data.CNES:download:64 - Stablishing connection with ftp.datasus.gov.br.
# 220 Microsoft FTP Service
# 2022-12-28 22:58:35.978 | DEBUG    | pysus.online_data.CNES:download:69 - Changing FTP work dir to: dissemin/publicos/CNES/200508_/Dados/LT/
# 2022-12-28 22:58:36.308 | DEBUG    | pysus.online_data.CNES:_fetch_file:99 - LTGO2204.dbc removed.
# 2022-12-28 22:58:36.329 | INFO     | pysus.online_data.CNES:download:83 - Data stored as parquet at /home/noetic-sierra/pysus/CNES_LTGO2204_.parquet
# 2022-12-28 22:58:36.462 | DEBUG    | pysus.online_data.CNES:download:64 - Stablishing connection with ftp.datasus.gov.br.
# 220 Microsoft FTP Service
# 2022-12-28 22:58:36.490 | DEBUG    | pysus.online_data.CNES:download:69 - Changing FTP work dir to: dissemin/publicos/CNES/200508_/Dados/LT/
# 2022-12-28 22:58:36.768 | DEBUG    | pysus.online_data.CNES:_fetch_file:99 - LTGO2205.dbc removed.
# 2022-12-28 22:58:36.780 | INFO     | pysus.online_data.CNES:download:83 - Data stored as parquet at /home/noetic-sierra/pysus/CNES_LTGO2205_.parquet
# 2022-12-28 22:58:36.894 | DEBUG    | pysus.online_data.CNES:download:64 - Stablishing connection with ftp.datasus.gov.br.
# 220 Microsoft FTP Service
# 2022-12-28 22:58:36.920 | DEBUG    | pysus.online_data.CNES:download:69 - Changing FTP work dir to: dissemin/publicos/CNES/200508_/Dados/LT/
# 2022-12-28 22:58:37.209 | DEBUG    | pysus.online_data.CNES:_fetch_file:99 - LTGO2206.dbc removed.
# 2022-12-28 22:58:37.225 | INFO     | pysus.online_data.CNES:download:83 - Data stored as parquet at /home/noetic-sierra/pysus/CNES_LTGO2206_.parquet
# 2022-12-28 22:58:37.338 | DEBUG    | pysus.online_data.CNES:download:64 - Stablishing connection with ftp.datasus.gov.br.
# 220 Microsoft FTP Service
# 2022-12-28 22:58:37.364 | DEBUG    | pysus.online_data.CNES:download:69 - Changing FTP work dir to: dissemin/publicos/CNES/200508_/Dados/LT/
# 2022-12-28 22:58:37.661 | DEBUG    | pysus.online_data.CNES:_fetch_file:99 - LTGO2207.dbc removed.
# 2022-12-28 22:58:37.747 | INFO     | pysus.online_data.CNES:download:83 - Data stored as parquet at /home/noetic-sierra/pysus/CNES_LTGO2207_.parquet
# 2022-12-28 22:58:37.890 | DEBUG    | pysus.online_data.CNES:download:64 - Stablishing connection with ftp.datasus.gov.br.
# 220 Microsoft FTP Service
# 2022-12-28 22:58:37.919 | DEBUG    | pysus.online_data.CNES:download:69 - Changing FTP work dir to: dissemin/publicos/CNES/200508_/Dados/LT/
# 2022-12-28 22:58:38.240 | DEBUG    | pysus.online_data.CNES:_fetch_file:99 - LTGO2208.dbc removed.
# 2022-12-28 22:58:38.253 | INFO     | pysus.online_data.CNES:download:83 - Data stored as parquet at /home/noetic-sierra/pysus/CNES_LTGO2208_.parquet
# 2022-12-28 22:58:38.414 | DEBUG    | pysus.online_data.CNES:download:64 - Stablishing connection with ftp.datasus.gov.br.
# 220 Microsoft FTP Service
# 2022-12-28 22:58:38.443 | DEBUG    | pysus.online_data.CNES:download:69 - Changing FTP work dir to: dissemin/publicos/CNES/200508_/Dados/LT/
# 2022-12-28 22:58:38.883 | DEBUG    | pysus.online_data.CNES:_fetch_file:99 - LTGO2209.dbc removed.
# 2022-12-28 22:58:38.903 | INFO     | pysus.online_data.CNES:download:83 - Data stored as parquet at /home/noetic-sierra/pysus/CNES_LTGO2209_.parquet
# 2022-12-28 22:58:39.066 | DEBUG    | pysus.online_data.CNES:download:64 - Stablishing connection with ftp.datasus.gov.br.
# 220 Microsoft FTP Service
# 2022-12-28 22:58:39.097 | DEBUG    | pysus.online_data.CNES:download:69 - Changing FTP work dir to: dissemin/publicos/CNES/200508_/Dados/LT/
# 2022-12-28 22:58:39.387 | DEBUG    | pysus.online_data.CNES:_fetch_file:99 - LTGO2210.dbc removed.
# 2022-12-28 22:58:39.399 | INFO     | pysus.online_data.CNES:download:83 - Data stored as parquet at /home/noetic-sierra/pysus/CNES_LTGO2210_.parquet
# 2022-12-28 22:58:39.527 | DEBUG    | pysus.online_data.CNES:download:64 - Stablishing connection with ftp.datasus.gov.br.
# 220 Microsoft FTP Service
# 2022-12-28 22:58:39.564 | DEBUG    | pysus.online_data.CNES:download:69 - Changing FTP work dir to: dissemin/publicos/CNES/200508_/Dados/LT/
# 2022-12-28 22:58:39.888 | DEBUG    | pysus.online_data.CNES:_fetch_file:99 - LTGO2211.dbc removed.
# 2022-12-28 22:58:39.900 | INFO     | pysus.online_data.CNES:download:83 - Data stored as parquet at /home/noetic-sierra/pysus/CNES_LTGO2211_.parquet

# %% [markdown]
# ## (v) Geral: todos os anos

# %%
df_main = pd.concat([
    df_12_19, #2019
    df_01_20,df_02_20,df_03_20,df_04_20,df_05_20,df_06_20,df_07_20,df_08_20,df_09_20,df_10_20,df_11_20,df_12_20, #2020
    df_01_21,df_02_21,df_03_21,df_04_21,df_05_21,df_06_21,df_07_21,df_08_21,df_09_21,df_10_21,df_11_21,df_12_21, #2021
    df_01_22,df_02_22,df_03_22,df_04_22,df_05_22,df_06_20,df_07_22,df_08_22,df_09_22,df_10_22,df_11_22 #2022
])

df_main
# Out:
#          CNES CODUFMUN REGSAUDE MICR_REG DISTRSAN DISTRADM TPGESTAO PF_PJ  \
# 0     9331603   520010                                            M     3
# 1     2335506   520013       15                                   M     3
# 2     2335506   520013       15                                   M     3
# 3     2335506   520013       15                                   M     3
# 4     2335506   520013       15                                   M     3
# ...       ...      ...      ...      ...      ...      ...      ...   ...
# 2939  2383691   522205      001                                   M     3
# 2940  2383691   522205      001                                   M     3
# 2941  2439883   522220       02                                   M     3
# 2942  2439883   522220       02                                   M     3
# 2943  2439883   522220       02                                   M     3
#
#             CPF_CNPJ NIV_DEP  ... TP_LEITO CODLEITO QT_EXIST QT_CONTR QT_SUS  \
# 0     00000000000000       3  ...        2       33        9        0      9
# 1     00269860000125       1  ...        2       41        2        0      2
# 2     00269860000125       1  ...        1       03        2        0      1
# 3     00269860000125       1  ...        4       10        1        0      1
# 4     00269860000125       1  ...        6       34        4        0      3
# ...              ...     ...  ...      ...      ...      ...      ...    ...
# 2939  00000000000000       3  ...        1       03        3        0      3
# 2940  00000000000000       3  ...        4       10        3        0      3
# 2941  00000000000000       3  ...        2       33        7        0      7
# 2942  00000000000000       3  ...        4       43        2        0      2
# 2943  00000000000000       3  ...        5       45        4        0      4
#
#      QT_NSUS COMPETEN NAT_JUR   ano mes
# 0          0   201912    1244  2019  12
# 1          0   201912    2062  2019  12
# 2          1   201912    2062  2019  12
# 3          0   201912    2062  2019  12
# 4          1   201912    2062  2019  12
# ...      ...      ...     ...   ...  ..
# 2939       0   202211    1244  2022  11
# 2940       0   202211    1244  2022  11
# 2941       0   202211    1244  2022  11
# 2942       0   202211    1244  2022  11
# 2943       0   202211    1244  2022  11
#
# [106226 rows x 30 columns]

# %% [markdown]
# * **Verificando os dtypes**

# %%
df_main.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 106226 entries, 0 to 2943
# Data columns (total 30 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   CNES      106226 non-null  object
#  1   CODUFMUN  106226 non-null  object
#  2   REGSAUDE  106226 non-null  object
#  3   MICR_REG  106226 non-null  object
#  4   DISTRSAN  106226 non-null  object
#  5   DISTRADM  106226 non-null  object
#  6   TPGESTAO  106226 non-null  object
#  7   PF_PJ     106226 non-null  object
#  8   CPF_CNPJ  106226 non-null  object
#  9   NIV_DEP   106226 non-null  object
#  10  CNPJ_MAN  106226 non-null  object
#  11  ESFERA_A  106226 non-null  object
#  12  ATIVIDAD  106226 non-null  object
#  13  RETENCAO  106226 non-null  object
#  14  NATUREZA  106226 non-null  object
#  15  CLIENTEL  106226 non-null  object
#  16  TP_UNID   106226 non-null  object
#  17  TURNO_AT  106226 non-null  object
#  18  NIV_HIER  106226 non-null  object
#  19  TERCEIRO  106226 non-null  object
#  20  TP_LEITO  106226 non-null  object
#  21  CODLEITO  106226 non-null  object
#  22  QT_EXIST  106226 non-null  int64
#  23  QT_CONTR  106226 non-null  int64
#  24  QT_SUS    106226 non-null  int64
#  25  QT_NSUS   106226 non-null  int64
#  26  COMPETEN  106226 non-null  object
#  27  NAT_JUR   106226 non-null  object
#  28  ano       106226 non-null  object
#  29  mes       106226 non-null  object
# dtypes: int64(4), object(26)
# memory usage: 25.1+ MB

# %% [markdown]
# # 3. Base de dados secundária (listagem de municípios de GO)
#
# * **Disponível em: https://www.ibge.gov.br/explica/codigos-dos-municipios.php#GO**

# %%
df_municipios=pd.read_csv('municipios_GO.csv').astype({'municipio':'str','codigo':'int32'})
df_municipios
# Out:
#               municipio   codigo
# 0       Abadia de Goiás  5200050
# 1             Abadiânia  5200100
# 2               Acreúna  5200134
# 3             Adelândia  5200159
# 4    Água Fria de Goiás  5200175
# ..                  ...      ...
# 241              Varjão  5221908
# 242          Vianópolis  5222005
# 243      Vicentinópolis  5222054
# 244            Vila Boa  5222203
# 245       Vila Propício  5222302
#
# [246 rows x 2 columns]
